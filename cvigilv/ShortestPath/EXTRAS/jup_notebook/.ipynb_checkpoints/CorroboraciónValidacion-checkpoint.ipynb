# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import ast

from sklearn import metrics
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from matplotlib import pyplot as plt

# %%
print("A.Schueller method")
AS_csv = '/home/carlos/Dropbox/chembl23_GS3_v2.mphase_gt_0.fp2.fix.txt.co.out'
AS_df = pd.read_csv(AS_csv,sep='\t',header=None, names=['Fold','QL','HT','Tc','HL','QT','TP'])
print(AS_df[AS_df['Tc'] > -99].info())
print(AS_df.nunique())
print(AS_df.describe())


print("\nC.Vigil method")
CV_csv = '/home/carlos/lppnet_AS.out'
CV_df = pd.read_csv(CV_csv,sep='\t',header=None, names=['Fold','QL','HT','Tc','Path','Steps','TP'])
CV_df['Tc'] = pd.to_numeric(CV_df['Tc'])
print(CV_df[CV_df['Steps'] != 'Null'].info())
print(CV_df.nunique())
print(CV_df.describe())

print(CV_df['Steps'].unique().tolist())
# Out:
# A.Schueller method
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1076887 entries, 0 to 1105103
# Data columns (total 7 columns):
# Fold    1076887 non-null int64
# QL      1076887 non-null object
# HT      1076887 non-null object
# Tc      1076887 non-null float64
# HL      1076887 non-null int64
# QT      1076887 non-null object
# TP      1076887 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 65.7+ MB
# None
# Fold       10
# QL       1232
# HT        897
# Tc      15263
# HL       1230
# QT       1230
# TP          2
# dtype: int64
#                Fold            Tc            HL            TP
# count  1.105104e+06  1.105104e+06  1.105104e+06  1.105104e+06
# mean   4.493506e+00 -2.284694e+00  6.849806e+02  8.723161e-03
# std    2.874535e+00  1.565583e+01  3.545904e+02  9.298965e-02
# min    0.000000e+00 -9.900000e+01 -1.000000e+00  0.000000e+00
# 25%    2.000000e+00  1.702130e-01  3.960000e+02  0.000000e+00
# 50%    4.000000e+00  2.410260e-01  7.280000e+02  0.000000e+00
# 75%    7.000000e+00  3.085110e-01  1.015000e+03  0.000000e+00
# max    9.000000e+00  1.000000e+00  1.231000e+03  1.000000e+00
#
# C.Vigil method
# /usr/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1105104 entries, 0 to 1105103
# Data columns (total 7 columns):
# Fold     1105104 non-null int64
# QL       1105104 non-null object
# HT       1105104 non-null object
# Tc       1105104 non-null float64
# Path     1105104 non-null object
# Steps    1105104 non-null int64
# TP       1105104 non-null bool
# dtypes: bool(1), float64(1), int64(2), object(3)
# memory usage: 60.1+ MB
# None
# Fold          10
# QL          1232
# HT           897
# Tc         15259
# Path     1105104
# Steps          1
# TP             2
# dtype: int64
#                Fold            Tc      Steps
# count  1.105104e+06  1.105104e+06  1105104.0
# mean   4.493506e+00 -2.317581e+00        2.0
# std    2.874535e+00  1.575379e+01        0.0
# min    0.000000e+00 -9.900000e+01        2.0
# 25%    2.000000e+00  1.698110e-01        2.0
# 50%    4.000000e+00  2.409640e-01        2.0
# 75%    7.000000e+00  3.087250e-01        2.0
# max    9.000000e+00  1.000000e+00        2.0
# [2]

# %%
def ROC(y_pred, y_scores, title, filename, color, string):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_pred, y_scores, pos_label=1)
    auc_roc = sklearn.metrics.auc(fpr,tpr)
    plt.plot(fpr, tpr, color=color, lw=2, label=string+' (Area = %0.2f)' % (auc_roc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')


def PR(y_pred, y_scores, title, filename, color, string):
    average_precision = average_precision_score(y_pred, y_scores)
    precision, recall, _ = precision_recall_curve(y_pred, y_scores)
    plt.step(recall, precision, color=color, where='post', label = string+' (AVG. Precision = %0.2f)' % (average_precision))
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])

# %%
plt.figure()
ROC(AS_df[AS_df['Tc'] > -99]['TP'], AS_df[AS_df['Tc'] > -99]['Tc'], 'AS_ROC', 'AS_ROC','orange','A.Schueller')
ROC(CV_df[CV_df['Tc'] > -99]['TP'], CV_df[CV_df['Tc'] > -99]['Tc'], 'CV_ROC', 'CV_ROC','purple','Redes')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right", prop={'size': 10})
#plt.show()
plt.savefig('ROC.png', dpi=300)
plt.close('all')

plt.figure()
PR(AS_df[AS_df['Tc'] > -99]['TP'], AS_df[AS_df['Tc'] > -99]['Tc'], 'AS_PR', 'AS_PR','orange','A.Schueller')
PR(CV_df[CV_df['Tc'] > -99]['TP'], CV_df[CV_df['Tc'] > -99]['Tc'], 'CV_PR', 'CV_PR','purple','Redes')
plt.title('Precision-Recall curve')
plt.legend(loc="upper right", prop={'size': 10})
#plt.show()
plt.savefig('PR.png', dpi=300)
plt.close('all')

# %%
AS_df = AS_df[['HT','QL','Tc']].sort_values(by=['HT','QL'],ascending=False)
AS_df = AS_df.rename(index=str, columns={"HT": "HT_AS", "QL": "QL_AS", "Tc":"Tc_AS"})
AS_df = AS_df.reset_index(drop=True)

CV_df = CV_df[['HT','QL','Tc']].sort_values(by=['HT','QL'],ascending=False)
CV_df = CV_df.rename(index=str, columns={"HT": "HT_CV", "QL": "QL_CV", "Tc":"Tc_CV"})
CV_df = CV_df.reset_index(drop=True)

print(AS_df)
print(CV_df)

result = pd.concat([AS_df, CV_df], axis=1, join_axes=[AS_df.index])
print(result)
result.to_csv('/home/carlos/ComparaciónMetodos.csv')
# Out:
#                  HT_AS         QL_AS     Tc_AS
# 0           CHEMBL6191     CHEMBL998  0.336100
# 1           CHEMBL6191     CHEMBL997  0.147368
# 2           CHEMBL6191    CHEMBL9967  0.316667
# 3           CHEMBL6191     CHEMBL990  0.273585
# 4           CHEMBL6191     CHEMBL989  0.224490
# 5           CHEMBL6191     CHEMBL986  0.065360
# 6           CHEMBL6191     CHEMBL982  0.271889
# 7           CHEMBL6191      CHEMBL98  0.303448
# 8           CHEMBL6191     CHEMBL978  0.169231
# 9           CHEMBL6191     CHEMBL973  0.298701
# 10          CHEMBL6191     CHEMBL964  0.086667
# 11          CHEMBL6191     CHEMBL960  0.287582
# 12          CHEMBL6191      CHEMBL96  0.107692
# 13          CHEMBL6191     CHEMBL959  0.101695
# 14          CHEMBL6191     CHEMBL957  0.340249
# 15          CHEMBL6191     CHEMBL956  0.189542
# 16          CHEMBL6191     CHEMBL954  0.247253
# 17          CHEMBL6191     CHEMBL953  0.295566
# 18          CHEMBL6191     CHEMBL945  0.271186
# 19          CHEMBL6191   CHEMBL94454  0.336493
# 20          CHEMBL6191     CHEMBL942  0.335766
# 21          CHEMBL6191     CHEMBL940  0.150794
# 22          CHEMBL6191      CHEMBL94  0.298969
# 23          CHEMBL6191     CHEMBL939  0.647059
# 24          CHEMBL6191     CHEMBL938  0.317757
# 25          CHEMBL6191   CHEMBL93645  0.307692
# 26          CHEMBL6191     CHEMBL934  0.278571
# 27          CHEMBL6191     CHEMBL932  0.413265
# 28          CHEMBL6191      CHEMBL93  0.240506
# 29          CHEMBL6191   CHEMBL92870  0.312139
# ...                ...           ...       ...
# 1105074  CHEMBL1075104    CHEMBL1071  0.193069
# 1105075  CHEMBL1075104    CHEMBL1070  0.197531
# 1105076  CHEMBL1075104    CHEMBL1065  0.293333
# 1105077  CHEMBL1075104    CHEMBL1060  0.011364
# 1105078  CHEMBL1075104     CHEMBL106  0.214634
# 1105079  CHEMBL1075104    CHEMBL1055  0.250000
# 1105080  CHEMBL1075104  CHEMBL105442  0.273171
# 1105081  CHEMBL1075104    CHEMBL1054  0.184685
# 1105082  CHEMBL1075104  CHEMBL105060  0.283401
# 1105083  CHEMBL1075104    CHEMBL1043  0.201439
# 1105084  CHEMBL1075104    CHEMBL1042  0.080645
# 1105085  CHEMBL1075104     CHEMBL104  0.240000
# 1105086  CHEMBL1075104  CHEMBL103667  0.421801
# 1105087  CHEMBL1075104    CHEMBL1034  0.316129
# 1105088  CHEMBL1075104   CHEMBL10316  0.292818
# 1105089  CHEMBL1075104     CHEMBL103  0.076923
# 1105090  CHEMBL1075104    CHEMBL1029  0.198830
# 1105091  CHEMBL1075104    CHEMBL1027  0.200000
# 1105092  CHEMBL1075104    CHEMBL1023  0.229630
# 1105093  CHEMBL1075104    CHEMBL1020  0.286996
# 1105094  CHEMBL1075104   CHEMBL10188  0.364641
# 1105095  CHEMBL1075104    CHEMBL1017  0.354497
# 1105096  CHEMBL1075104    CHEMBL1016  0.333333
# 1105097  CHEMBL1075104  CHEMBL101253  0.338798
# 1105098  CHEMBL1075104    CHEMBL1009  0.233533
# 1105099  CHEMBL1075104    CHEMBL1008  0.304598
# 1105100  CHEMBL1075104    CHEMBL1006  0.114130
# 1105101  CHEMBL1075104   CHEMBL10041  0.236025
# 1105102  CHEMBL1075104    CHEMBL1002  0.257669
# 1105103  CHEMBL1075104    CHEMBL1000  0.277372
#
# [1105104 rows x 3 columns]
#                  HT_CV         QL_CV     Tc_CV
# 0           CHEMBL6191     CHEMBL998  0.336100
# 1           CHEMBL6191     CHEMBL997  0.147368
# 2           CHEMBL6191    CHEMBL9967  0.361582
# 3           CHEMBL6191     CHEMBL990  0.273585
# 4           CHEMBL6191     CHEMBL989  0.224490
# 5           CHEMBL6191     CHEMBL986  0.065360
# 6           CHEMBL6191     CHEMBL982  0.271889
# 7           CHEMBL6191      CHEMBL98  0.286667
# 8           CHEMBL6191     CHEMBL978  0.169231
# 9           CHEMBL6191     CHEMBL973  0.298701
# 10          CHEMBL6191     CHEMBL964  0.086667
# 11          CHEMBL6191     CHEMBL960  0.311377
# 12          CHEMBL6191      CHEMBL96  0.107692
# 13          CHEMBL6191     CHEMBL959  0.101695
# 14          CHEMBL6191     CHEMBL957  0.340249
# 15          CHEMBL6191     CHEMBL956  0.222222
# 16          CHEMBL6191     CHEMBL954  0.272059
# 17          CHEMBL6191     CHEMBL953  0.324742
# 18          CHEMBL6191     CHEMBL945  0.271186
# 19          CHEMBL6191   CHEMBL94454  0.336493
# 20          CHEMBL6191     CHEMBL942  0.335766
# 21          CHEMBL6191     CHEMBL940  0.150794
# 22          CHEMBL6191      CHEMBL94  0.319588
# 23          CHEMBL6191     CHEMBL939  0.647059
# 24          CHEMBL6191     CHEMBL938  0.300412
# 25          CHEMBL6191   CHEMBL93645  0.307692
# 26          CHEMBL6191     CHEMBL934  0.278571
# 27          CHEMBL6191     CHEMBL932  0.413265
# 28          CHEMBL6191      CHEMBL93  0.240506
# 29          CHEMBL6191   CHEMBL92870  0.312139
# ...                ...           ...       ...
# 1105074  CHEMBL1075104    CHEMBL1071  0.193069
# 1105075  CHEMBL1075104    CHEMBL1070  0.197531
# 1105076  CHEMBL1075104    CHEMBL1065  0.317164
# 1105077  CHEMBL1075104    CHEMBL1060  0.013605
# 1105078  CHEMBL1075104     CHEMBL106  0.216867
# 1105079  CHEMBL1075104    CHEMBL1055  0.250000
# 1105080  CHEMBL1075104  CHEMBL105442  0.273171
# 1105081  CHEMBL1075104    CHEMBL1054  0.262136
# 1105082  CHEMBL1075104  CHEMBL105060  0.283401
# 1105083  CHEMBL1075104    CHEMBL1043  0.201439
# 1105084  CHEMBL1075104    CHEMBL1042  0.100000
# 1105085  CHEMBL1075104     CHEMBL104  0.240000
# 1105086  CHEMBL1075104  CHEMBL103667  0.341991
# 1105087  CHEMBL1075104    CHEMBL1034  0.316129
# 1105088  CHEMBL1075104   CHEMBL10316  0.292818
# 1105089  CHEMBL1075104     CHEMBL103  0.076923
# 1105090  CHEMBL1075104    CHEMBL1029  0.198830
# 1105091  CHEMBL1075104    CHEMBL1027  0.200000
# 1105092  CHEMBL1075104    CHEMBL1023  0.229630
# 1105093  CHEMBL1075104    CHEMBL1020  0.286996
# 1105094  CHEMBL1075104   CHEMBL10188  0.354167
# 1105095  CHEMBL1075104    CHEMBL1017  0.354497
# 1105096  CHEMBL1075104    CHEMBL1016  0.305936
# 1105097  CHEMBL1075104  CHEMBL101253  0.338798
# 1105098  CHEMBL1075104    CHEMBL1009  0.233533
# 1105099  CHEMBL1075104    CHEMBL1008  0.326203
# 1105100  CHEMBL1075104    CHEMBL1006  0.114130
# 1105101  CHEMBL1075104   CHEMBL10041  0.272727
# 1105102  CHEMBL1075104    CHEMBL1002  0.257669
# 1105103  CHEMBL1075104    CHEMBL1000  0.238372
#
# [1105104 rows x 3 columns]
#                  HT_AS         QL_AS     Tc_AS          HT_CV         QL_CV  \
# 0           CHEMBL6191     CHEMBL998  0.336100     CHEMBL6191     CHEMBL998
# 1           CHEMBL6191     CHEMBL997  0.147368     CHEMBL6191     CHEMBL997
# 2           CHEMBL6191    CHEMBL9967  0.316667     CHEMBL6191    CHEMBL9967
# 3           CHEMBL6191     CHEMBL990  0.273585     CHEMBL6191     CHEMBL990
# 4           CHEMBL6191     CHEMBL989  0.224490     CHEMBL6191     CHEMBL989
# 5           CHEMBL6191     CHEMBL986  0.065360     CHEMBL6191     CHEMBL986
# 6           CHEMBL6191     CHEMBL982  0.271889     CHEMBL6191     CHEMBL982
# 7           CHEMBL6191      CHEMBL98  0.303448     CHEMBL6191      CHEMBL98
# 8           CHEMBL6191     CHEMBL978  0.169231     CHEMBL6191     CHEMBL978
# 9           CHEMBL6191     CHEMBL973  0.298701     CHEMBL6191     CHEMBL973
# 10          CHEMBL6191     CHEMBL964  0.086667     CHEMBL6191     CHEMBL964
# 11          CHEMBL6191     CHEMBL960  0.287582     CHEMBL6191     CHEMBL960
# 12          CHEMBL6191      CHEMBL96  0.107692     CHEMBL6191      CHEMBL96
# 13          CHEMBL6191     CHEMBL959  0.101695     CHEMBL6191     CHEMBL959
# 14          CHEMBL6191     CHEMBL957  0.340249     CHEMBL6191     CHEMBL957
# 15          CHEMBL6191     CHEMBL956  0.189542     CHEMBL6191     CHEMBL956
# 16          CHEMBL6191     CHEMBL954  0.247253     CHEMBL6191     CHEMBL954
# 17          CHEMBL6191     CHEMBL953  0.295566     CHEMBL6191     CHEMBL953
# 18          CHEMBL6191     CHEMBL945  0.271186     CHEMBL6191     CHEMBL945
# 19          CHEMBL6191   CHEMBL94454  0.336493     CHEMBL6191   CHEMBL94454
# 20          CHEMBL6191     CHEMBL942  0.335766     CHEMBL6191     CHEMBL942
# 21          CHEMBL6191     CHEMBL940  0.150794     CHEMBL6191     CHEMBL940
# 22          CHEMBL6191      CHEMBL94  0.298969     CHEMBL6191      CHEMBL94
# 23          CHEMBL6191     CHEMBL939  0.647059     CHEMBL6191     CHEMBL939
# 24          CHEMBL6191     CHEMBL938  0.317757     CHEMBL6191     CHEMBL938
# 25          CHEMBL6191   CHEMBL93645  0.307692     CHEMBL6191   CHEMBL93645
# 26          CHEMBL6191     CHEMBL934  0.278571     CHEMBL6191     CHEMBL934
# 27          CHEMBL6191     CHEMBL932  0.413265     CHEMBL6191     CHEMBL932
# 28          CHEMBL6191      CHEMBL93  0.240506     CHEMBL6191      CHEMBL93
# 29          CHEMBL6191   CHEMBL92870  0.312139     CHEMBL6191   CHEMBL92870
# ...                ...           ...       ...            ...           ...
# 1105074  CHEMBL1075104    CHEMBL1071  0.193069  CHEMBL1075104    CHEMBL1071
# 1105075  CHEMBL1075104    CHEMBL1070  0.197531  CHEMBL1075104    CHEMBL1070
# 1105076  CHEMBL1075104    CHEMBL1065  0.293333  CHEMBL1075104    CHEMBL1065
# 1105077  CHEMBL1075104    CHEMBL1060  0.011364  CHEMBL1075104    CHEMBL1060
# 1105078  CHEMBL1075104     CHEMBL106  0.214634  CHEMBL1075104     CHEMBL106
# 1105079  CHEMBL1075104    CHEMBL1055  0.250000  CHEMBL1075104    CHEMBL1055
# 1105080  CHEMBL1075104  CHEMBL105442  0.273171  CHEMBL1075104  CHEMBL105442
# 1105081  CHEMBL1075104    CHEMBL1054  0.184685  CHEMBL1075104    CHEMBL1054
# 1105082  CHEMBL1075104  CHEMBL105060  0.283401  CHEMBL1075104  CHEMBL105060
# 1105083  CHEMBL1075104    CHEMBL1043  0.201439  CHEMBL1075104    CHEMBL1043
# 1105084  CHEMBL1075104    CHEMBL1042  0.080645  CHEMBL1075104    CHEMBL1042
# 1105085  CHEMBL1075104     CHEMBL104  0.240000  CHEMBL1075104     CHEMBL104
# 1105086  CHEMBL1075104  CHEMBL103667  0.421801  CHEMBL1075104  CHEMBL103667
# 1105087  CHEMBL1075104    CHEMBL1034  0.316129  CHEMBL1075104    CHEMBL1034
# 1105088  CHEMBL1075104   CHEMBL10316  0.292818  CHEMBL1075104   CHEMBL10316
# 1105089  CHEMBL1075104     CHEMBL103  0.076923  CHEMBL1075104     CHEMBL103
# 1105090  CHEMBL1075104    CHEMBL1029  0.198830  CHEMBL1075104    CHEMBL1029
# 1105091  CHEMBL1075104    CHEMBL1027  0.200000  CHEMBL1075104    CHEMBL1027
# 1105092  CHEMBL1075104    CHEMBL1023  0.229630  CHEMBL1075104    CHEMBL1023
# 1105093  CHEMBL1075104    CHEMBL1020  0.286996  CHEMBL1075104    CHEMBL1020
# 1105094  CHEMBL1075104   CHEMBL10188  0.364641  CHEMBL1075104   CHEMBL10188
# 1105095  CHEMBL1075104    CHEMBL1017  0.354497  CHEMBL1075104    CHEMBL1017
# 1105096  CHEMBL1075104    CHEMBL1016  0.333333  CHEMBL1075104    CHEMBL1016
# 1105097  CHEMBL1075104  CHEMBL101253  0.338798  CHEMBL1075104  CHEMBL101253
# 1105098  CHEMBL1075104    CHEMBL1009  0.233533  CHEMBL1075104    CHEMBL1009
# 1105099  CHEMBL1075104    CHEMBL1008  0.304598  CHEMBL1075104    CHEMBL1008
# 1105100  CHEMBL1075104    CHEMBL1006  0.114130  CHEMBL1075104    CHEMBL1006
# 1105101  CHEMBL1075104   CHEMBL10041  0.236025  CHEMBL1075104   CHEMBL10041
# 1105102  CHEMBL1075104    CHEMBL1002  0.257669  CHEMBL1075104    CHEMBL1002
# 1105103  CHEMBL1075104    CHEMBL1000  0.277372  CHEMBL1075104    CHEMBL1000
#
#             Tc_CV
# 0        0.336100
# 1        0.147368
# 2        0.361582
# 3        0.273585
# 4        0.224490
# 5        0.065360
# 6        0.271889
# 7        0.286667
# 8        0.169231
# 9        0.298701
# 10       0.086667
# 11       0.311377
# 12       0.107692
# 13       0.101695
# 14       0.340249
# 15       0.222222
# 16       0.272059
# 17       0.324742
# 18       0.271186
# 19       0.336493
# 20       0.335766
# 21       0.150794
# 22       0.319588
# 23       0.647059
# 24       0.300412
# 25       0.307692
# 26       0.278571
# 27       0.413265
# 28       0.240506
# 29       0.312139
# ...           ...
# 1105074  0.193069
# 1105075  0.197531
# 1105076  0.317164
# 1105077  0.013605
# 1105078  0.216867
# 1105079  0.250000
# 1105080  0.273171
# 1105081  0.262136
# 1105082  0.283401
# 1105083  0.201439
# 1105084  0.100000
# 1105085  0.240000
# 1105086  0.341991
# 1105087  0.316129
# 1105088  0.292818
# 1105089  0.076923
# 1105090  0.198830
# 1105091  0.200000
# 1105092  0.229630
# 1105093  0.286996
# 1105094  0.354167
# 1105095  0.354497
# 1105096  0.305936
# 1105097  0.338798
# 1105098  0.233533
# 1105099  0.326203
# 1105100  0.114130
# 1105101  0.272727
# 1105102  0.257669
# 1105103  0.238372
#
# [1105104 rows x 6 columns]
